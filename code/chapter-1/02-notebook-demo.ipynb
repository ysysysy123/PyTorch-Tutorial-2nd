# %% [markdown]
# # 这里是Markdown单元格

# %%
import torch

print("Hello World, Hello PyTorch {}".format(torch.__version__))

print("\nCUDA is available:{}, version is {}".format(torch.cuda.is_available(), torch.version.cuda))

print("\ndevice_name: {}".format(torch.cuda.get_device_name(0)))
# Out:
# Hello World, Hello PyTorch 2.4.1+cu121
#
# CUDA is available:True, version is 12.1
#
# device_name: NVIDIA GeForce RTX 4080 Laptop GPU

# %% [markdown]
# # 两个神奇操作
# ! 以及 %% 使用

# %%
# !nvidia-smi
# !time /t
# !dir
# Out:
# Sun Sep 13 00:50:57 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.91.07              Driver Version: 595.91.07      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   48C    P0             23W /  120W |    1279MiB /  12282MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A            7012      G   /usr/bin/gnome-shell                    355MiB |
# |    0   N/A  N/A            7163      G   /usr/local/awesun/awesun                 65MiB |
# |    0   N/A  N/A            7199      G   /usr/bin/clash-verge                      3MiB |
# |    0   N/A  N/A            7402    C+G   ...exec/xdg-desktop-portal-gnome          7MiB |
# |    0   N/A  N/A            7414      G   /usr/bin/Xwayland                         7MiB |
# |    0   N/A  N/A           11226      G   ...rack-uuid=3190708988185955192        294MiB |
# |    0   N/A  N/A           15995    C+G   ...708988185955192 --log-level=3         75MiB |
# |    0   N/A  N/A          199153    C+G   /usr/bin/nautilus                        39MiB |
# |    0   N/A  N/A          203509      G   ...708989122997041 --log-level=2         12MiB |
# |    0   N/A  N/A          211211    C+G   ...rack-uuid=3190708988185955192         73MiB |
# |    0   N/A  N/A          211871    C+G   ...rack-uuid=3190708988185955192         92MiB |
# +-----------------------------------------------------------------------------------------+
# zsh:1: 没有那个文件或目录: /t
# /t  0.00s user 0.00s system 87% cpu 0.001 total
# 01-hello-pytorch.py	03-torch-compile-performance.py
# 02-notebook-demo.ipynb	03-torch-compile.ipynb

# %%
# %%timeit
a = []
for i in range(10):
    a.append(i)
# Out:
# 143 ns ± 1 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %%time
a = []
for i in range(1000000):
    a.append(i)
# Out:
# CPU times: user 31.9 ms, sys: 8 ms, total: 39.9 ms
# Wall time: 39.2 ms
