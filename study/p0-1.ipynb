# %%
def iter_batches(samples, batch_size):
    if batch_size <= 0:
        raise ValueError("batch_size must be greater than 0")

    batches = []

    for start in range(0, len(samples), batch_size):
        batch = samples[start:start + batch_size]
        batches.append(batch)

    return batches

print(iter_batches([], 2))
print(iter_batches([10, 20, 30, 40], 2))
# Out:
# []
# [[10, 20], [30, 40]]

# %%
samples = [
    {"x": 1.0, "y": 0},
    {"x": 2.0, "y": 1},
    {"x": 3.0, "y": 1},
]

def iter_batches(samples, batch_size):
    if batch_size <= 0:
        raise ValueError("batch_size must be greater than 0")

    batches = []

    for start in range(0, len(samples), batch_size):
        batch = samples[start:start + batch_size]
        batches.append(batch)

    return batches

batch_size = 2
iter_batches(samples, batch_size)
# Out:
# [[{'x': 1.0, 'y': 0}, {'x': 2.0, 'y': 1}], [{'x': 3.0, 'y': 1}]]

# %%
def get_first_batch(samples, batch_size):
    if batch_size <= 0:
        raise ValueError("batch_size must be greater than 0")

    return samples[:batch_size]

# %%
def iter_batches(samples, batch_size):
    if batch_size <= 0:
        raise ValueError("batch_size must be greater than 0")

    batches = []

    for start in range(0, len(samples), batch_size):
        batch = samples[start:start + batch_size]
        batches.append(batch)

    return batches


samples = [
    {"x": 1, "y": 10},
    {"x": 2, "y": 20},
    {"x": 3, "y": 30},
]

print(iter_batches(samples, 2))
print(iter_batches([], 2))
# Out:
# [[{'x': 1, 'y': 10}, {'x': 2, 'y': 20}], [{'x': 3, 'y': 30}]]
# []
